# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(100,1)
y = 4 +3 * X+np.random.randn(100,1)

# %%
plt.plot(X,y,'b.')
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0,2,0,15])
plt.show()

# %%
# Calculate the means of X and y
mean_X = np.mean(X)
mean_y = np.mean(y)

# %%
# Calculate b1 and b0
b1 = np.sum((X - mean_X) * (y - mean_y)) / np.sum((X - mean_X) ** 2)
b0 = mean_y - b1 * mean_X

# %%
# Calculate the predicted y values
y_pred = b0 + b1 * X

# %%
# Calculate the coefficient of determination (R^2)
ss_total = np.sum((y - mean_y) ** 2)
ss_residual = np.sum((y - y_pred) ** 2)
r2 = 1 - (ss_residual / ss_total)

# %%
# Display the results
print(f"b1 (slope): {b1}")
print(f"b0 (intercept): {b0}")
print(f"R^2 (coefficient of determination): {r2}")
# Out:
# b1 (slope): 2.883798541308661
# b0 (intercept): 4.271991866720663
# R^2 (coefficient of determination): 0.7038540336463395

# %%
# Plot the regression line
plt.plot(X, y_pred, color='red', label='Regression line')

# %%
# Assuming 'X' is the original data with 100 points used to calculate y_pred
# Regenerate predictions using X_new if you want to plot against new x-values
y_pred_new = b0 + b1 * X_new

plt.plot(X_new, y_pred_new, 'r-')  # Plot using the new predictions
plt.plot(X, y, 'b.')
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
# Add labels and title
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.show()

# %% [markdown]
# Task 2
